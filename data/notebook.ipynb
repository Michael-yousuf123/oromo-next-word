# %%
import requests
from urllib.request import urlopen
from bs4 import BeautifulSoup
html = urlopen('https://www.bbc.com/afaanoromoo')
bs = BeautifulSoup(html.read(), 'html.parser')

# %%
url = 'https://www.bbc.com/afaanoromoo'
req = requests.get(url)

# %%
content = req.content
soup = BeautifulSoup(content, 'html.parser')

# %%
import pandas as pd
import re
links = soup.find_all('a', class_="focusIndicatorDisplayBlock bbc-uk8dsi e1d658bg0")# Find all elements with the tag <a>
urls = []
for link in links:
  urls.append(link.attrs['href'])
  print("Link:", link.get("href"), "Text:", link.string)
# Out:
# Link: https://www.bbc.com/afaanoromoo/articles/c511z0l3rplo Text: Shawaa Lixaatti 'finxaaleyyiin Amaaraa' mana cidhaa boombiin haleeluun  namoota 20 ol ajjeesan-Aanga'aa
# Link: https://www.bbc.com/afaanoromoo/articles/cd11eg6e14no Text: 'Hojjettoonni dhokatanii waajira keessa jiraatu': Itoophiyaatti jireenyi hangam qaala'e?
# Link: https://www.bbc.com/afaanoromoo/articles/clww8rzpdrjo Text: Loltootni mootummaafi WBO jumlaan gudeeduu dabalatee yakkoota hedduu Gujiitti raawwachuun ibsame
# Link: https://www.bbc.com/afaanoromoo/live/czkkp4d1eymt Text: None
# Link: https://www.bbc.com/afaanoromoo/articles/c2llydz5pz9o Text: Wixineen labsii aangoo manneen murtii qooddatuufi mirga lammiilee daangessu yaaddoo uume
# Link: https://www.bbc.com/afaanoromoo/articles/c4nnydze4p0o Text: Namoota Hajjiif Saawudii deeman keessaa 14 sababa ho'a jabaan du'an
# Link: https://www.bbc.com/afaanoromoo/articles/c2llyz51jn0o Text: Putiin biyyoota Lixaa aarsuuf Kooriyaa Kaabaa waliin 'hariiroo jabeessuuf'
# ...

# %%
import pandas as pd
import re
getLinks = soup.find_all('a', class_="focusIndicatorDisplayBlock bbc-uk8dsi e1d658bg0")# Find all elements with the tag <a>
links = []
for link in getLinks:
    if link.string == None:
        continue
    links.append(link.attrs['href'])
    print("Link:", link.get("href"), "Text:", link.string)
# Out:
# Link: https://www.bbc.com/afaanoromoo/articles/c511z0l3rplo Text: Shawaa Lixaatti 'finxaaleyyiin Amaaraa' mana cidhaa boombiin haleeluun  namoota 20 ol ajjeesan-Aanga'aa
# Link: https://www.bbc.com/afaanoromoo/articles/cd11eg6e14no Text: 'Hojjettoonni dhokatanii waajira keessa jiraatu': Itoophiyaatti jireenyi hangam qaala'e?
# Link: https://www.bbc.com/afaanoromoo/articles/clww8rzpdrjo Text: Loltootni mootummaafi WBO jumlaan gudeeduu dabalatee yakkoota hedduu Gujiitti raawwachuun ibsame
# Link: https://www.bbc.com/afaanoromoo/articles/c2llydz5pz9o Text: Wixineen labsii aangoo manneen murtii qooddatuufi mirga lammiilee daangessu yaaddoo uume
# Link: https://www.bbc.com/afaanoromoo/articles/c4nnydze4p0o Text: Namoota Hajjiif Saawudii deeman keessaa 14 sababa ho'a jabaan du'an
# Link: https://www.bbc.com/afaanoromoo/articles/c2llyz51jn0o Text: Putiin biyyoota Lixaa aarsuuf Kooriyaa Kaabaa waliin 'hariiroo jabeessuuf'
# ...

# %%
links
# Out:
# ['https://www.bbc.com/afaanoromoo/articles/c511z0l3rplo',
#  'https://www.bbc.com/afaanoromoo/articles/cd11eg6e14no',
#  'https://www.bbc.com/afaanoromoo/articles/clww8rzpdrjo',
#  'https://www.bbc.com/afaanoromoo/articles/c2llydz5pz9o',
#  'https://www.bbc.com/afaanoromoo/articles/c4nnydze4p0o',
#  'https://www.bbc.com/afaanoromoo/articles/c2llyz51jn0o',
#  'https://www.bbc.com/afaanoromoo/articles/c066y36dxkpo',
#  'https://www.bbc.com/afaanoromoo/articles/c0dd2e3082po',
#  'https://www.bbc.com/afaanoromoo/articles/cpwwp7y8qw0o',
#  'https://www.bbc.com/afaanoromoo/articles/c0xx20w09wxo',
#  'https://www.bbc.com/afaanoromoo/articles/c1vv6yegdylo',
#  'https://www.bbc.com/afaanoromoo/articles/c999e0wjqy2o',
#  'https://www.bbc.com/afaanoromoo/articles/c900xle1yqwo',
#  'https://www.bbc.com/afaanoromoo/articles/c4nn51q53xjo',
#  'https://www.bbc.com/afaanoromoo/articles/c888e9vzyj0o',
#  'https://www.bbc.com/afaanoromoo/articles/cqvv7y638p4o',
# ...

# %%
def text_mining(urls):
    for url in urls:
        print(url)
        req = requests.get(url)
        c = req.content
        soup = BeautifulSoup(c, "html.parser")
        article_text = ''
        article = soup.find("div", {"class":"bbc-bg8vrv"}).findAll('p')
        for element in article:
            article_text += '\n' + ''.join(element.findAll(text = True))
        print(article_text)
    return article_text

# %%
arti = text_mining(links)
# Out:
# https://www.bbc.com/afaanoromoo/articles/c511z0l3rplo
# /tmp/ipykernel_92735/886493679.py:10: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   article_text += '\n' + ''.join(element.findAll(text = True))
# Madda suuraa, Miidiyaa Hawwaasaa
# Shawaa Lixaa aanaa Noonnootti 'finxaaleyyiin Amaaraa' haleellaa mana cidhaarratti raawwataniin yoo xiqqaate namoota 24 ajjeesuusaanii Komand Postiin aanichaa Obbo Tashoomaa Sobboqaa BBCtti himan.
# Obbo Tashoomaan haleellaan kun guyyaa Sanbatatti bari’u gara bariirra raawwatamuu himan.
# Haleellaa kana 'finxaaleyyii Amaaraa' raawwachuu kan himan Obbo Tashoomaan, "namoonni kunneen osoo mana cidhaa jiranii duubaan mana itti cufuun boombiidhaan haleelan.
#  Warra birmannaa dhufan ammoo alatti rasaasaan haleelaa turan. Manicha keessaa namni bahe tokkoyyuu hin jiru. Achuma keessatti gubatan. Homtuu hin hafne," jechuun waan mudate ibsu.
# ...

# %%
text_mining(urls)
# Out:
# https://www.bbc.com/afaanoromoo/articles/c511z0l3rplo
# /tmp/ipykernel_92735/886493679.py:10: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   article_text += '\n' + ''.join(element.findAll(text = True))
# Madda suuraa, Miidiyaa Hawwaasaa
# Shawaa Lixaa aanaa Noonnootti 'finxaaleyyiin Amaaraa' haleellaa mana cidhaarratti raawwataniin yoo xiqqaate namoota 24 ajjeesuusaanii Komand Postiin aanichaa Obbo Tashoomaa Sobboqaa BBCtti himan.
# Obbo Tashoomaan haleellaan kun guyyaa Sanbatatti bari’u gara bariirra raawwatamuu himan.
# Haleellaa kana 'finxaaleyyii Amaaraa' raawwachuu kan himan Obbo Tashoomaan, "namoonni kunneen osoo mana cidhaa jiranii duubaan mana itti cufuun boombiidhaan haleelan.
#  Warra birmannaa dhufan ammoo alatti rasaasaan haleelaa turan. Manicha keessaa namni bahe tokkoyyuu hin jiru. Achuma keessatti gubatan. Homtuu hin hafne," jechuun waan mudate ibsu.
# ...

# %%
def text_mining(links):
    articles=[]
    for link in links:
        print(url)
        req = requests.get(link)
        c = req.content
        soup = BeautifulSoup(c, "html.parser")
        article_text = ''
        article = soup.find("div", {"class":"bbc-bg8vrv"}).findAll('p')
        for element in article:
            article_text = article_text + '\n' .join(element.findAll(text = True))
            articles.append(article_text)
    return articles

# %%
ar = text_mining(urls)
# Out:
# https://www.bbc.com/afaanoromoo/articles/c7229j0yv8zo
# /tmp/ipykernel_38365/3517987269.py:11: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   article_text = article_text + '\n' .join(element.findAll(text = True))
# https://www.bbc.com/afaanoromoo/articles/c7229j0yv8zo
# https://www.bbc.com/afaanoromoo/articles/c7229j0yv8zo
# https://www.bbc.com/afaanoromoo/articles/c7229j0yv8zo
# https://www.bbc.com/afaanoromoo/articles/c7229j0yv8zo
# https://www.bbc.com/afaanoromoo/articles/c7229j0yv8zo
# https://www.bbc.com/afaanoromoo/articles/c7229j0yv8zo
# https://www.bbc.com/afaanoromoo/articles/c7229j0yv8zo
# https://www.bbc.com/afaanoromoo/articles/c7229j0yv8zo
# https://www.bbc.com/afaanoromoo/articles/c7229j0yv8zo
# https://www.bbc.com/afaanoromoo/articles/c7229j0yv8zo
# https://www.bbc.com/afaanoromoo/articles/c7229j0yv8zo
# https://www.bbc.com/afaanoromoo/articles/c7229j0yv8zo
# https://www.bbc.com/afaanoromoo/articles/c7229j0yv8zo
# ...

# %%
import pandas as pd
def text_mining(urls):
    data = []
    for url in urls:
        print(url)
        req = requests.get(url)
        c = req.content
        soup = BeautifulSoup(c, "html.parser")
        link = url
        title = soup.find('h1',class_="bbc-csfh25 e1p3vdyi0").text
        article_text = ''
        article = soup.find("div", {"class":"bbc-bg8vrv"}).findAll('p')
        for element in article:
            article_text += '\n' + ''.join(element.findAll(text = True))
        data.append({
            'Title':title,
            'Link':url,
            'Contents':article
            })
    df = pd.DataFrame(data).to_csv('news.csv',index=False)
    print(df)
    return article_text

# %%
a = text_mining(links)
# Out:
# https://www.bbc.com/afaanoromoo/articles/c511z0l3rplo
# /tmp/ipykernel_92735/3888317810.py:14: DeprecationWarning: The 'text' argument to find()-type methods is deprecated. Use 'string' instead.
#   article_text += '\n' + ''.join(element.findAll(text = True))
# https://www.bbc.com/afaanoromoo/articles/cd11eg6e14no
# https://www.bbc.com/afaanoromoo/articles/clww8rzpdrjo
# https://www.bbc.com/afaanoromoo/articles/c2llydz5pz9o
# https://www.bbc.com/afaanoromoo/articles/c4nnydze4p0o
# https://www.bbc.com/afaanoromoo/articles/c2llyz51jn0o
# https://www.bbc.com/afaanoromoo/articles/c066y36dxkpo
# https://www.bbc.com/afaanoromoo/articles/c0dd2e3082po
# https://www.bbc.com/afaanoromoo/articles/cpwwp7y8qw0o
# https://www.bbc.com/afaanoromoo/articles/c0xx20w09wxo
# https://www.bbc.com/afaanoromoo/articles/c1vv6yegdylo
# https://www.bbc.com/afaanoromoo/articles/c999e0wjqy2o
# https://www.bbc.com/afaanoromoo/articles/c900xle1yqwo
# https://www.bbc.com/afaanoromoo/articles/c4nn51q53xjo
# ...

# %%
df.
